# %%
import pandas as pd

# %%
import geopandas as gpd
import fiona
from fiona.drvsupport import supported_drivers

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg

# %%
#Import KML Driver
#gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'
#supported_drivers['LIBKML'] = 'rw'
gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'

# %% [markdown]
# ### Hospitals Data
#
# Downloaded from: https://geoportal.hawaii.gov/datasets/hospitals-1/explore?location=20.639400%2C-157.361100%2C8.61&showTable=true
#
# * `Description`: Locations of hospitals in the State of Hawaii as of November 2021.
# * `Source`:  State Department of Health, Office of Health Care Assurance (OHCA).
# * `Lowest Geographic Scale`: Latitute, Longitude; Address
# * `Data formats available`: csv, geojson, kml
#
# ```
# Name:  Facility Name
# Licensed_Beds: Licensed Bed Count
# Island: Island
# Mailing_Address: Mailing Address
# Physical_Address: Physical Address
# Phone: Phone Number
# Alt_Phone: Alternative Phone Number
# Fax: Fax
# POC: Point of Contact
# Website: Website
# Accred_Status: Accreditation Status* (TJC, N/A)
# Cert_Status: Certification Status
# Critical_Access_Hosp: Critical Access Hospital ** (Yes, No)
# Provider Number: Provider Number
# ```

# %%
# Tabular data    
data = pd.read_csv("data/hospitals/Hospitals.csv")
data.head(3)
# Out:
#             X          Y  objectid                     name  licensed_beds  \
# 0 -157.757104  21.381406         1  ADVENTIST HEALTH CASTLE            160
# 1 -155.470496  20.076394         2      HALE HO’OLA HAMAKUA             11
# 2 -157.810021  21.409491         3    HAWAII STATE HOSPITAL            202
#
#    island                                mailing_address  \
# 0    OAHU     640 Ulukahiki Street, Kailua, Hawaii 96734
# 1  HAWAII  45-547 Plumeria Street, Honokaa, Hawaii 96727
# 2    OAHU   45-710 Keaahala Road, Kaneohe, Hawaii  96744
#
#                                 physical_address           phone  alt_phone  \
# 0     640 Ulukahiki Street, Kailua, Hawaii 96734  (808) 263-5500        NaN
# 1  45-547 Plumeria Street, Honokaa, Hawaii 96727  (808) 932-4100        NaN
# 2   45-710 Keaahala Road, Kaneohe, Hawaii  96744  (808) 247-2191        NaN
#
#               fax                                             poc  \
# 0  (808) 263-5123                    Kathy Raethel, President/CEO
# 1  (808) 775-9977                David A. Culbreth, Administrator
# 2  (808) 247-7335  Run F. Heidelberg, DNP, APRN-RX, Administrator
#
#                                    website accred_status cert_status  \
# 0  https://www.adventisthealth.org/castle/           TJC           X
# 1        https://www.halehoolahamakua.org/           NaN           X
# 2               https://health.hawaii.gov/           TJC         NaN
#
#   critical_access_hosp  provider_num
# 0                  NaN      120006.0
# 1                    X      121307.0
# 2                  NaN           NaN

# %%
# geojson    

data = gpd.read_file("data/hospitals/Hospitals.geojson")
df.head
# Out:
# <bound method NDFrame.head of     objectid                                             name  licensed_beds  \
# 0          1                          ADVENTIST HEALTH CASTLE            160
# 1          2                              HALE HO’OLA HAMAKUA             11
# 2          3                            HAWAII STATE HOSPITAL            202
# 3          4                              HILO MEDICAL CENTER            166
# 4          5                                      KAHI MOHALA             88
# 5          6                            KAHUKU MEDICAL CENTER             21
# 6          7                       KAISER FOUNDATION HOSPITAL            295
# 7          8  KAPIOLANI MEDICAL CENTER for WOMEN and CHILDREN            253
# 8          9                                     KAU HOSPITAL             21
# 9         10                 KAUAI VETERANS MEMORIAL HOSPITAL             25
# 10        11                                  KOHALA HOSPITAL              6
# 11        12                          KONA COMMUNITY HOSPITAL             94
# 12        13                           KUAKINI MEDICAL CENTER            212
# 13        14                                    KULA HOSPITAL              9
# 14        15                         LANAI COMMUNITY HOSPITAL              4
# 15        16                                   LEAHI HOSPITAL              4
# 16        17                     MAUI MEMORIAL MEDICAL CENTER            219
# 17        18                         MOLOKAI GENERAL HOSPITAL             15
# 18        19          QUEEN’S NORTH HAWAII COMMUNITY HOSPITAL             35
# 19        20                         PALI MOMI MEDICAL CENTER            118
# 20        21           REHABILITATION HOSPITAL OF THE PACIFIC             82
# 21        22               SAMUEL MAHELONA  MEMORIAL HOSPITAL             14
# 22        23                  SHRINERS HOSPITAL FOR  CHILDREN             24
# 23        24                       STRAUB CLINIC AND HOSPITAL            159
# 24        25                       THE QUEEN’S MEDICAL CENTER            535
# 25        26     THE QUEEN’S MEDICAL CENTER – HALE PULAMA MAU             40
# 26        27           THE QUEEN’S MEDICAL CENTER – WEST OAHU            104
# 27        28                         WAHIAWA GENERAL HOSPITAL             42
# 28        29                         WILCOX MEMORIAL HOSPITAL             72
#
#      island                                    mailing_address  \
# 0      OAHU         640 Ulukahiki Street, Kailua, Hawaii 96734
# 1    HAWAII      45-547 Plumeria Street, Honokaa, Hawaii 96727
# 2      OAHU       45-710 Keaahala Road, Kaneohe, Hawaii  96744
# 3    HAWAII        1190 Waianuenue Avenue, Hilo, Hawaii  96720
# 4      OAHU  91-2301 Fort Weaver Road, Ewa Beach, Hawaii  9...
# 5      OAHU       56-117 Pualalea Street, Kahuku, Hawaii 96731
# 6      OAHU        3288 Moanalua Road, Honolulu, Hawaii  96819
# 7      OAHU        1319 Punahou Street, Honolulu, Hawaii 96826
# 8    HAWAII                  P.O. Box 40, Pahala, Hawaii 96777
# 9     KAUAI                 P.O. Box 337, Waimea, Hawaii 96796
# 10   HAWAII                  P.O. Box 10, Kapaau, Hawaii 96755
# 11   HAWAII  79-1019 Haukapila Street, Kealakekua, Hawaii 9...
# 12     OAHU   347 North Kuakini Street, Honolulu, Hawaii 96817
# 13     MAUI          100 Keokea Place, Kula, Hawaii 96790-7450
# 14    LANAI          P.O. Box 630650, Lanai City, Hawaii 96763
# 15     OAHU        3675 Kilauea Avenue, Honolulu, Hawaii 96816
# 16     MAUI         221 Mahalani Street, Wailuku, Hawaii 96793
# 17  MOLOKAI             P.O. Box 408, Kaunakakai, Hawaii 96748
# 18   HAWAII               P.O. Box 2799, Kamuela, Hawaii 96743
# 19     OAHU          98-1079 Moanalua Road, Aiea, Hawaii 96701
# 16  https://www.mauihealth.org/locations/maui-memo...           TJC
# 17  https://www.queens.org/molokai/molokai-general...           TJC
# 18  https://www.queens.org/north-hawaii/north-hawa...           TJC
# 19     https://www.hawaiipacifichealth.org/pali-momi/           TJC
# 20                     https://www.rehabhospital.org/           TJC
# 21  http://kauai.hhsc.org/facilities/samuel-mahelo...          None
# 22   https://www.shrinershospitalsforchildren.org/shc           TJC
# 23        https://www.hawaiipacifichealth.org/straub/           TJC
# 24  https://www.queens.org/the-queens-medical-cent...           TJC
# 25  https://www.queens.org/the-queens-medical-cent...           TJC
# 26  https://www.queens.org/west-oahu/queens-medica...           TJC
# 27                        https://wahiawageneral.org/           TJC
# 28        https://www.hawaiipacifichealth.org/wilcox/           TJC
#
#    cert_status critical_access_hosp  provider_num                     geometry
# 0            X                 None      120006.0  POINT (-157.75710 21.38141)
# 1            X                    X      121307.0  POINT (-155.47050 20.07639)
# 2         None                 None           NaN  POINT (-157.81002 21.40949)
# 3            X                 None      120005.0  POINT (-155.11298 19.71753)
# 4            X                 None      124001.0  POINT (-158.02605 21.37181)
# 5            X                    X      121304.0  POINT (-157.95222 21.67734)
# 6            X                 None      120011.0  POINT (-157.90040 21.36257)
# 7            X                 None      123300.0  POINT (-157.83430 21.30026)
# 8            X                    X      121301.0  POINT (-155.47200 19.26292)
# 9            X                    X      121300.0  POINT (-159.66561 21.95464)
# 10           X                    X      121302.0  POINT (-155.81276 20.23470)
# 11           X                 None      120019.0  POINT (-155.91867 19.52031)
# 12           X                 None      120007.0  POINT (-157.85638 21.32237)
# 13           X                    X      121308.0  POINT (-156.35854 20.70223)
# 14           X                    X      121305.0  POINT (-156.91999 20.82679)
# 15           X                 None      122001.0  POINT (-157.80140 21.27372)
# 16           X                 None      120002.0  POINT (-156.48868 20.88414)
# 17           X                    X      121303.0  POINT (-157.01551 21.09015)
# 18           X                 None      120028.0  POINT (-155.67153 20.02193)
# 19           X                 None      120026.0  POINT (-157.93872 21.38340)
# 20           X                 None      123025.0  POINT (-157.85510 21.32107)
# 21           X                    X      121306.0  POINT (-159.31413 22.08771)
# 22           X                 None      123301.0  POINT (-157.83442 21.30018)
# 23           X                 None      120022.0  POINT (-157.85074 21.30225)
# 24           X                 None      120001.0  POINT (-157.85521 21.30754)
# 25           X                 None      120001.0  POINT (-157.86311 21.32707)
# 26           X                 None      120001.0  POINT (-158.02607 21.37114)
# 27           X                 None      120004.0  POINT (-158.02731 21.49871)
# 28           X                 None      120014.0  POINT (-159.36640 21.98558)  >

# %%
#KML
df2 = gpd.read_file("data/hospitals/Hospitals.kml", driver="KML")

# %%
df2.head(5)
# Out:
#                       Name Description                     geometry
# 0  ADVENTIST HEALTH CASTLE              POINT (-157.75710 21.38141)
# 1      HALE HO’OLA HAMAKUA              POINT (-155.47050 20.07639)
# 2    HAWAII STATE HOSPITAL              POINT (-157.81002 21.40949)
# 3      HILO MEDICAL CENTER              POINT (-155.11298 19.71753)
# 4              KAHI MOHALA              POINT (-158.02605 21.37181)

# %% [markdown]
# ### Adult Residential Care Homes Data
#
# Downloaded from: https://geoportal.hawaii.gov/datasets/HiStateGIS::adult-residential-care-homes/about
#
# * `Description`: Locations of adult residential care homes in the State of Hawaii as of November 2021.
# * `Source`:  Hawaii State Department of Health Office of Health Care Assurance (OHCA).
# * `Lowest Geographic Scale`: Latitute, Longitude; Address
# * `Data formats available`: csv, geojson, kml
#
# ```
# Facility_Name: Facility Name
# Facility_Type: Facility Type (definitions below)
# Licensee: Name of License Holder
# Address: Facility Address
# City: City
# State: State
# Island: Island
# Phone: Phone Number
# License_Num: License Number
# License_Exp: License Expiration
# Males: # of male vacancies in the facility (Nov 2021)
# Females: # of female vacancies in the facility (Nov 2021)
# Capacity: Overall Capacity of the Facility
# Amb_Type: Ambulatory Type (definitions below)
# Wheelchair_Appr: Is Facility Wheelchair Approved? (Yes or no)
# Diet_Type: Type of Diet Approved in Facility (Regular or Special)
# ```

# %%
# Tabular data    
data1 = pd.read_csv("data/Adult_Residential_Care_Homes/Adult_Residential_Care_Homes.csv")
data1.head(3)
# Out:
#             X          Y  objectid  \
# 0 -157.864657  21.344071         1
# 1 -157.947627  21.387788         2
# 2 -157.934424  21.382605         3
#
#                                        facility_name  \
# 0                                              3 J's
# 1  808 Adult Residential Care Home/Expanded Care LLC
# 2                    888 Adult Residential Care Home
#
#                                  facility_type           licensee  \
# 0  Type I Expanded Adult Residential Care Home  Geronimo Castillo
# 1  Type I Expanded Adult Residential Care Home   Novelyn Llarenas
# 2  Type I Expanded Adult Residential Care Home   Victor Laforteza
#
#                  address      city   state island         phone license_num  \
# 0      1624 Perry Street  Honolulu  Hawaii   Oahu  8.088487e+09      1334-C
# 1   98-209 Kanuku Street      Aiea  Hawaii   Oahu  8.087000e+09      1344-C
# 2  98-550 Kaamilo Street      Aiea  Hawaii   Oahu  8.088884e+09      1647-C
#
#               license_exp  males  females  capacity    amb_type  \
# 0  2022/07/31 00:00:00+00    2.0      1.0       5.0  Ambulatory
# 1  2022/08/31 00:00:00+00    0.0      1.0       5.0  Ambulatory
# 2  2022/03/31 00:00:00+00    NaN      NaN       5.0         NaN
#
#   wheelchair_appr diet_type
# 0             Yes   Special
# 1             Yes   Special
# 2              No       NaN

# %%
#geojson

df_adult_care_homes = gpd.read_file("data/Adult_Residential_Care_Homes/Adult_Residential_Care_Homes.geojson")
df_adult_care_homes.head(3)
# Out:
#    objectid                                      facility_name  \
# 0         1                                              3 J's
# 1         2  808 Adult Residential Care Home/Expanded Care LLC
# 2         3                    888 Adult Residential Care Home
#
#                                  facility_type           licensee  \
# 0  Type I Expanded Adult Residential Care Home  Geronimo Castillo
# 1  Type I Expanded Adult Residential Care Home   Novelyn Llarenas
# 2  Type I Expanded Adult Residential Care Home   Victor Laforteza
#
#                  address      city   state island         phone license_num  \
# 0      1624 Perry Street  Honolulu  Hawaii   Oahu  8.088487e+09      1334-C
# 1   98-209 Kanuku Street      Aiea  Hawaii   Oahu  8.087000e+09      1344-C
# 2  98-550 Kaamilo Street      Aiea  Hawaii   Oahu  8.088884e+09      1647-C
#
#                 license_exp  males  females  capacity    amb_type  \
# 0 2022-07-31 00:00:00+00:00    2.0      1.0       5.0  Ambulatory
# 1 2022-08-31 00:00:00+00:00    0.0      1.0       5.0  Ambulatory
# 2 2022-03-31 00:00:00+00:00    NaN      NaN       5.0        None
#
#   wheelchair_appr diet_type                     geometry
# 0             Yes   Special  POINT (-157.86466 21.34407)
# 1             Yes   Special  POINT (-157.94763 21.38779)
# 2              No      None  POINT (-157.93442 21.38260)

# %%
#KML
df2_adult_care_homes = gpd.read_file("data/Adult_Residential_Care_Homes/Adult_Residential_Care_Homes.kml", driver="KML")
df2_adult_care_homes.head(3)
# Out:
#   Name Description                     geometry
# 0                   POINT (-157.86466 21.34407)
# 1                   POINT (-157.94763 21.38779)
# 2                   POINT (-157.93442 21.38260)

# %% [markdown]
# ### Assisted Living Facilities Data
#
# Downloaded from: https://geoportal.hawaii.gov/datasets/HiStateGIS::assisted-living-facilities/about
#
# * `Description`: Locations of adult residential care homes in the State of Hawaii as of November 2021.
# * `Source`:  Hawaii State Department of Health Office of Health Care Assurance (OHCA).
# * `Lowest Geographic Scale`: Latitute, Longitude; Address
# * `Data formats available`: csv, geojson, kml
#
# ```
# Facility_Name: Facility Name
# Facility_Type: Facility Type (definitions below)
# Licensee: Name of License Holder
# Address: acility Address
# City:City
# State:State
# Island:Island
# Phone:Phone Number
# License_Num:License Number
# License_Exp:License Expiration
# Males:# of male vacancies in the facility (Nov 2021)
# Females:# of female vacancies in the facility (Nov 2021)
# Capacity:Overall Capacity of the Facility
# Amb_Type:Ambulatory Type (definitions below)
# Wheelchair_Appr: Is Facility Wheelchair Approved? (Yes or no)
# Diet_Type: Type of Diet Approved in Facility (Regular or Special)
# ```

# %%
# Tabular data    
data3 = pd.read_csv("data/assisted living facilities/Assisted_Living_Facilities.csv")
data3.head(3)
# Out:
#             X          Y  objectid                                       name  \
# 0 -157.848743  21.323116         1                               15 Craigside
# 1 -157.833433  21.301697         2               Arcadia Retirement Residence
# 2 -157.716056  21.292595         3  Hawaii Kai Retirement Comm Phase I and II
#
#                address      city  zipcode island   phone_num  \
# 0   15 Craigside Place  Honolulu    96817   Oahu  8085237000
# 1  1434 Punahou Street  Honolulu    96822   Oahu  8089410941
# 2  428 Kawaihae Street  Honolulu    96825   Oahu  8083959599
#
#               license_exp license_num
# 0  2022/06/30 00:00:00+00      16-ALF
# 1  2023/08/31 00:00:00+00       1-ALF
# 2  2022/04/30 00:00:00+00      12-ALF

# %%
#geojson
df3_assisted_living_facilities = gpd.read_file("data/assisted living facilities/Assisted_Living_Facilities.kml", driver="KML")
df3_assisted_living_facilities.head(3)
# Out:
#                                         Name Description  \
# 0                               15 Craigside
# 1               Arcadia Retirement Residence
# 2  Hawaii Kai Retirement Comm Phase I and II
#
#                       geometry
# 0  POINT (-157.84874 21.32312)
# 1  POINT (-157.83343 21.30170)
# 2  POINT (-157.71606 21.29260)

# %% [markdown]
# ### Age of Structure Data
# #### Year Structure Built
#
# Downloaded from: https://data.census.gov/table/ACSDT5Y2019.B25034g=040XX00US15$1500000&y=2019&tid=ACSDT5Y2019.B25034
#
# * `Description`: Year structure built
# * `Source`:  U.S. Census Bureau, 2015-2019 American Community Survey 5-Year Estimates
# * `Data formats available`: csv
# * `GEO_ID`: 1500000US150010201001 (FIPS code 1500000US:Country, 15:Hawaii State, 001:County, 02010:Census Track,01:Blockgroup)
#
# ```
# Column Name	Label
# GEO_ID	Geography
# NAME	Geographic Area Name
# B25034_001E	Estimate Total:
# B25034_001M	Margin of Error Total:
# B25034_002E	Estimate Total: Built 2014 or later
# B25034_002M	Margin of Error Total: Built 2014 or later
# B25034_003E	Estimate Total: Built 2010 to 2013
# B25034_003M	Margin of Error Total: Built 2010 to 2013
# B25034_004E	Estimate Total: Built 2000 to 2009
# B25034_004M	Margin of Error Total: Built 2000 to 2009
# B25034_005E	Estimate Total: Built 1990 to 1999
# B25034_005M	Margin of Error Total: Built 1990 to 1999
# B25034_006E	Estimate Total: Built 1980 to 1989
# B25034_006M	Margin of Error Total: Built 1980 to 1989
# B25034_007E	Estimate Total: Built 1970 to 1979
# B25034_007M	Margin of Error Total: Built 1970 to 1979
# B25034_008E	Estimate Total: Built 1960 to 1969
# B25034_008M	Margin of Error Total: Built 1960 to 1969
# B25034_009E	Estimate Total: Built 1950 to 1959
# B25034_009M	Margin of Error Total: Built 1950 to 1959
# B25034_010E	Estimate Total: Built 1940 to 1949
# B25034_010M	Margin of Error Total: Built 1940 to 1949
# B25034_011E	Estimate Total: Built 1939 or earlier
# B25034_011M	Margin of Error Total: Built 1939 or earlier
# ```

# %%
data4 = pd.read_csv('data/age of structure/ACSDT5Y2019.B25034-Data.csv')
data4.head(4)
# Out:
#                   GEO_ID                                               NAME  \
# 0              Geography                               Geographic Area Name
# 1  1500000US150010201001  Block Group 1, Census Tract 201, Hawaii County...
# 2  1500000US150010201002  Block Group 2, Census Tract 201, Hawaii County...
# 3  1500000US150010201003  Block Group 3, Census Tract 201, Hawaii County...
#
#         B25034_001E              B25034_001M  \
# 0  Estimate!!Total:  Margin of Error!!Total:
# 1               977                      114
# 2               454                      101
# 3               272                       76
#
#                              B25034_002E  \
# 0  Estimate!!Total:!!Built 2014 or later
# 1                                      3
# 2                                      4
# 3                                      0
#
#                                     B25034_002M  \
# 0  Margin of Error!!Total:!!Built 2014 or later
# 1                                             4
# 2                                             7
# 3                                            11
#
#                             B25034_003E  \
# 0  Estimate!!Total:!!Built 2010 to 2013
# 1                                     2
# 2                                     0
# 3                                     0
#
#                                    B25034_003M  \
# 0  Margin of Error!!Total:!!Built 2010 to 2013
# 1                                            3
# 2                                           11
# 3                                           11
#
#                             B25034_004E  \
# 0  Estimate!!Total:!!Built 2000 to 2009
# 1                                    64
# 2                                    99
# 3                                    41
#
#                                    B25034_004M  ...  \
# 0  Margin of Error!!Total:!!Built 2000 to 2009  ...
# 1                                           34  ...
# 2                                           75  ...
# 3                                           39  ...
#
#                                    B25034_007M  \
# 0  Margin of Error!!Total:!!Built 1970 to 1979
# 1                                           45
# 2                                           19
# 3                                           50
#
#                             B25034_008E  \
# 0  Estimate!!Total:!!Built 1960 to 1969
# 1                                   164
# 2                                     8
# 3                                    10
#
#                                    B25034_008M  \
# 0  Margin of Error!!Total:!!Built 1960 to 1969
# 1                                           51
# 2                                            9
# 3                                           15
#
#                             B25034_009E  \
# 0  Estimate!!Total:!!Built 1950 to 1959
# 1                                   148
# 2                                    12
# 3                                     3
#
#                                    B25034_009M  \
# 0  Margin of Error!!Total:!!Built 1950 to 1959
# 1                                           50
# 2                                           11
# 3                                            5
#
#                             B25034_010E  \
# 0  Estimate!!Total:!!Built 1940 to 1949
# 1                                    84
# 2                                    64
# 3                                     0
#
#                                    B25034_010M  \
# 0  Margin of Error!!Total:!!Built 1940 to 1949
# 1                                           88
# 2                                           24
# 3                                           11
#
#                                B25034_011E  \
# 0  Estimate!!Total:!!Built 1939 or earlier
# 1                                       52
# 2                                       94
# 3                                       42
#
#                                       B25034_011M Unnamed: 24
# 0  Margin of Error!!Total:!!Built 1939 or earlier         NaN
# 1                                              22         NaN
# 2                                              60         NaN
# 3                                              40         NaN
#
# [4 rows x 25 columns]

# %% [markdown]
# ### Sea Level Rise Exposure Data - 1.1 Ft. Scenario
#
# Downloaded from: https://geoportal.hawaii.gov/search?collection=Dataset&groupIds=a247b90d2fd14f60a64c0c75db5d5731
#
# * `Description`: Estimated extent of chronic flooding due to multiple coastal hazards, modeled using a 1.1 foot sea level rise scenario.
# * `Source`:  Hawaii Statewide GIS Program Open Data Site
# * `Lowest Geographic Scale`: Multipolygon, Latitute, Longitude;
# * `Data formats available`: csv, geojson, kml, shapefile
#
# ```
#
# ```

# %%
data5 = pd.read_csv('data/sea_level_rise_exposure/1.1ft/SLR_Exposure_Area_-_1.1_Ft._Scenario.csv')
data5.head(3)
# Out:
#    objectid  id  st_areashape  st_perimetershape
# 0         1   1  1.626753e+07       1.365255e+06
# 1         2   0  1.185934e+07       1.023204e+06
# 2         3   1  1.223127e+06       1.830724e+05

# %%
data6 = gpd.read_file('data/sea_level_rise_exposure/1.1ft/SLR_Exposure_Area_-_1.1_Ft._Scenario.geojson')
data6.head()
# Out:
#    objectid  id  st_areashape  st_perimetershape  \
# 0         1   1  1.626753e+07       1.365255e+06
# 1         2   0  1.185934e+07       1.023204e+06
# 2         3   1  1.223127e+06       1.830724e+05
# 3         4   0  7.960696e+06       7.450346e+05
# 4         5   1  3.803924e+06       4.277066e+05
#
#                                             geometry
# 0  MULTIPOLYGON (((-155.34006 19.22734, -155.3401...
# 1  MULTIPOLYGON (((-159.78249 22.05861, -159.7824...
# 2  MULTIPOLYGON (((-156.93192 20.92210, -156.9322...
# 3  MULTIPOLYGON (((-156.50022 20.79772, -156.5002...
# 4  MULTIPOLYGON (((-157.14802 21.09239, -157.1480...

# %%
data7 = gpd.read_file('data/sea_level_rise_exposure/1.1ft/SLR_Exposure_Area_-_1.1_Ft._Scenario.kml')
data7.head(3)
# Out:
#   Name Description                                           geometry
# 0                   MULTIPOLYGON (((-155.34006 19.22734, -155.3401...
# 1                   MULTIPOLYGON (((-159.78249 22.05861, -159.7824...
# 2                   MULTIPOLYGON (((-156.93192 20.92210, -156.9322...

# %%
data8 = gpd.read_file('data/sea_level_rise_exposure/1.1ft/SLR_Exposure_Area_-_1.1_Ft._Scenario_ShapeFile')
data8.plot(alpha=.4, color='gray', edgecolor='black')
# Out:
# <Axes: >

# %% [markdown]
# ### Sea Level Rise Exposure Data - 2.0 Ft. Scenario
#
# Downloaded from: https://geoportal.hawaii.gov/search?collection=Dataset&groupIds=a247b90d2fd14f60a64c0c75db5d5731
#
# * `Description`: Estimated extent of chronic flooding due to multiple coastal hazards, modeled using a 2.0 foot sea level rise scenario.
# * `Source`:  Hawaii Statewide GIS Program Open Data Site
# * `Lowest Geographic Scale`: Multipolygon, Latitute, Longitude;
# * `Data formats available`: csv, geojson, kml, shapefile
#
# ```
#
# ```

# %%
data9 = pd.read_csv('data/sea_level_rise_exposure/2.0ft/SLR_Exposure_Area_-_2.0_Ft._Scenario.csv')
data9.head(3)
# Out:
#    objectid  id  st_areashape  st_perimetershape
# 0         1   1  1.742507e+07       1.420933e+06
# 1         2   0  1.613553e+07       1.082830e+06
# 2         3   1  1.337530e+06       1.904737e+05

# %%
data10 = gpd.read_file('data/sea_level_rise_exposure/2.0ft/SLR_Exposure_Area_-_2.0_Ft._Scenario.geojson')
data10.head()
# Out:
#    objectid  id  st_areashape  st_perimetershape  \
# 0         1   1  1.742507e+07       1.420933e+06
# 1         2   0  1.613553e+07       1.082830e+06
# 2         3   1  1.337530e+06       1.904737e+05
# 3         4   0  9.846578e+06       8.195439e+05
# 4         5   1  6.620965e+06       6.483648e+05
#
#                                             geometry
# 0  MULTIPOLYGON (((-155.34006 19.22734, -155.3401...
# 1  MULTIPOLYGON (((-159.78216 22.06026, -159.7821...
# 2  MULTIPOLYGON (((-156.91505 20.91916, -156.9150...
# 3  MULTIPOLYGON (((-156.50200 20.79698, -156.5020...
# 4  MULTIPOLYGON (((-157.11872 21.09841, -157.1187...

# %%
data11 = gpd.read_file('data/sea_level_rise_exposure/2.0ft/SLR_Exposure_Area_-_2.0_Ft._Scenario.kml')
data11.head(3)
# Out:
#   Name Description                                           geometry
# 0                   MULTIPOLYGON (((-155.34006 19.22734, -155.3401...
# 1                   MULTIPOLYGON (((-159.78216 22.06026, -159.7821...
# 2                   MULTIPOLYGON (((-156.91505 20.91916, -156.9150...

# %%
data12 = gpd.read_file('data/sea_level_rise_exposure/2.0ft/SLR_Exposure_Area_-_2.0_Ft._Scenario_ShapeFile')
data12.plot(alpha=.4, color='gray', edgecolor='black')
# Out:
# <Axes: >
